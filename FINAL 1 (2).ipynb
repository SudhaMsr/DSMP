# %%
# %pip install matplotlib seaborn scikit-learn

# %% [markdown]
# ## Import required libraries:

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Load dataset

# %%
## load data set
data = pd.read_csv('fake_transactional_data_24 (1).csv')
## head
data.head()
# Out:
#    from_totally_fake_account  monopoly_money_amount  \
# 0                    10371.0                   4.00
# 1                    88339.0                   2.40
# 2                    18555.0                   2.40
# 3                    18555.0                   4.10
# 4                    80792.0                   1.95
#
#   to_randomly_generated_account not_happened_yet_date
# 0                        CINEMA            01/01/2025
# 1                         40544            01/01/2025
# 2                         85149            01/01/2025
# 3           HIPSTER_COFFEE_SHOP            01/01/2025
# 4                         18555            01/01/2025

# %% [markdown]
# ## Explore data

# %%
data.shape
# Out:
# (10148280, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10148280 entries, 0 to 10148279
# Data columns (total 4 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   from_totally_fake_account      float64
#  1   monopoly_money_amount          float64
#  2   to_randomly_generated_account  object
#  3   not_happened_yet_date          object
# dtypes: float64(2), object(2)
# memory usage: 309.7+ MB

# %%
data.dtypes
# Out:
# from_totally_fake_account        float64
# monopoly_money_amount            float64
# to_randomly_generated_account     object
# not_happened_yet_date             object
# dtype: object

# %%
data.columns
# Out:
# Index(['from_totally_fake_account', 'monopoly_money_amount',
#        'to_randomly_generated_account', 'not_happened_yet_date'],
#       dtype='object')

# %% [markdown]
# ## Missing values

# %%
data.isnull()
# Out:
#           from_totally_fake_account  monopoly_money_amount  \
# 0                             False                  False
# 1                             False                  False
# 2                             False                  False
# 3                             False                  False
# 4                             False                  False
# ...                             ...                    ...
# 10148275                      False                  False
# 10148276                      False                  False
# 10148277                      False                  False
# 10148278                      False                  False
# 10148279                      False                  False
#
#           to_randomly_generated_account  not_happened_yet_date
# 0                                 False                  False
# 1                                 False                  False
# 2                                 False                  False
# 3                                 False                  False
# 4                                 False                  False
# ...                                 ...                    ...
# 10148275                          False                  False
# 10148276                          False                  False
# 10148277                          False                  False
# 10148278                          False                  False
# 10148279                          False                  False
#
# [10148280 rows x 4 columns]

# %%
missing_values = data.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  from_totally_fake_account        0
# monopoly_money_amount            0
# to_randomly_generated_account    0
# not_happened_yet_date            0
# dtype: int64

# %% [markdown]
# ### Statistical information of given data

# %%
data.describe()
# Out:
#        from_totally_fake_account  monopoly_money_amount
# count               1.014828e+07           1.014828e+07
# mean                5.080502e+04           1.839348e+01
# std                 2.893710e+04           8.612323e+01
# min                 1.000000e+03           1.450000e+00
# 25%                 2.530400e+04           2.650000e+00
# 50%                 5.078100e+04           6.000000e+00
# 75%                 7.563300e+04           1.200000e+01
# max                 1.009880e+05           1.995000e+03

# %%
data.describe().transpose()
# Out:
#                                 count          mean           std      min  \
# from_totally_fake_account  10148280.0  50805.021701  28937.100678  1000.00
# monopoly_money_amount      10148280.0     18.393485     86.123232     1.45
#
#                                 25%      50%      75%       max
# from_totally_fake_account  25304.00  50781.0  75633.0  100988.0
# monopoly_money_amount          2.65      6.0     12.0    1995.0

# %%
data.describe(include=['O'])
# Out:
#        to_randomly_generated_account not_happened_yet_date
# count                       10148280              10148280
# unique                         14300                   364
# top                              PUB            12/12/2025
# freq                          834380                 52379

# %%
data.describe().astype(int)
# Out:
#        from_totally_fake_account  monopoly_money_amount
# count                   10148280               10148280
# mean                       50805                     18
# std                        28937                     86
# min                         1000                      1
# 25%                        25304                      2
# 50%                        50781                      6
# 75%                        75633                     12
# max                       100988                   1995

# %%
data.describe(include='all')
# Out:
#         from_totally_fake_account  monopoly_money_amount  \
# count                1.014828e+07           1.014828e+07
# unique                        NaN                    NaN
# top                           NaN                    NaN
# freq                          NaN                    NaN
# mean                 5.080502e+04           1.839348e+01
# std                  2.893710e+04           8.612323e+01
# min                  1.000000e+03           1.450000e+00
# 25%                  2.530400e+04           2.650000e+00
# 50%                  5.078100e+04           6.000000e+00
# 75%                  7.563300e+04           1.200000e+01
# max                  1.009880e+05           1.995000e+03
#
#        to_randomly_generated_account not_happened_yet_date
# count                       10148280              10148280
# unique                         14300                   364
# top                              PUB            12/12/2025
# freq                          834380                 52379
# mean                             NaN                   NaN
# std                              NaN                   NaN
# min                              NaN                   NaN
# 25%                              NaN                   NaN
# 50%                              NaN                   NaN
# 75%                              NaN                   NaN
# max                              NaN                   NaN

# %%
#data.transpose()

# %%
##sns.heatmap(data.corr(),annot=True)-- char to int

# %%
## convert data (char to int) to plot heatmap

# %%
## float to integer
data['from_totally_fake_account'] = data['from_totally_fake_account'].astype(int)

# %%
# nearest integer/ rounding
data['monopoly_money_amount'] = data['monopoly_money_amount'].round().astype(int)

# %%
data.head(3)
# Out:
#    from_totally_fake_account  monopoly_money_amount  \
# 0                      10371                      4
# 1                      88339                      2
# 2                      18555                      2
#
#   to_randomly_generated_account not_happened_yet_date
# 0                        CINEMA            01/01/2025
# 1                         40544            01/01/2025
# 2                         85149            01/01/2025

# %% [markdown]
# `to_randomly_generated_account` => Transfered to account

# %%
from tqdm import tqdm

new_col  = list()
randomly_generated_account = data['to_randomly_generated_account'].tolist()
for x in tqdm(randomly_generated_account, total=len(randomly_generated_account)):
    try:
        val = int(x) 
        new_col.append(val)
    except ValueError:
        new_col.append(x)
# Out:
# 100%|██████████| 10148280/10148280 [00:04<00:00, 2119832.41it/s]

# %%
filtered_cols = list()
for i in tqdm(new_col, total=len(new_col)):
    if type(i) == str:
        filtered_cols.append(i)
    else:
        filtered_cols.append("TRANSFERED_TO_ACCOUNT")
# Out:
# 100%|██████████| 10148280/10148280 [00:01<00:00, 6709495.35it/s]

# %%
data['to_randomly_generated_account'] = filtered_cols

# %%
# Convert 'not_happened_yet_date' to datetime
data['not_happened_yet_date'] = pd.to_datetime(data['not_happened_yet_date'], format='%d/%m/%Y')

# %%
agg_features = data.groupby('from_totally_fake_account').agg(
    Average_Transaction_Amount=('monopoly_money_amount', 'mean'),
    Total_Transaction_Amount=('monopoly_money_amount', 'sum'),
    Transaction_Frequency=('monopoly_money_amount', 'count')
).reset_index()


data['year_month'] = data['not_happened_yet_date'].dt.to_period('M')
time_agg = data.groupby('year_month').agg(
    Total_Transactions=('monopoly_money_amount', 'count'),
    Average_Amount_Per_Transaction=('monopoly_money_amount', 'mean')
).reset_index()

time_agg.head()
# Out:
#   year_month  Total_Transactions  Average_Amount_Per_Transaction
# 0    2025-01              854543                       17.944117
# 1    2025-02              776515                       18.835740
# 2    2025-03              871002                       18.053508
# 3    2025-04              812316                       18.416386
# 4    2025-05              881706                       17.934387

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Normalize the aggregated features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(agg_features.drop('from_totally_fake_account', axis=1))

# Apply K-Means Clustering
kmeans = KMeans(n_clusters=3, random_state=42)
agg_features['Segment'] = kmeans.fit_predict(scaled_features)

agg_features.head()
# Out:
#    from_totally_fake_account  Average_Transaction_Amount  \
# 0                       1000                   16.726901
# 1                       1002                   14.947267
# 2                       1006                   10.165671
# 3                       1018                   19.499379
# 4                       1053                   14.705838
#
#    Total_Transaction_Amount  Transaction_Frequency  Segment
# 0                     28603                   1710        2
# 1                     15590                   1043        0
# 2                     18715                   1841        2
# 3                     15697                    805        0
# 4                     19397                   1319        0

# %%
# Visualization of customer segments
plt.figure(figsize=(10, 6))
sns.scatterplot(data=agg_features, x='Total_Transaction_Amount', y='Transaction_Frequency', hue='Segment', palette='viridis')
plt.title('Customer Segmentation based on Transaction Amount and Frequency')
plt.xlabel('Total Transaction Amount')
plt.ylabel('Transaction Frequency')
plt.legend(title='Segment')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['monopoly_money_amount'], bins=30, kde=True)
plt.title('Distribution of Monopoly Money Amount')
plt.xlabel('Monopoly Money Amount')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 8))
time_agg.plot(x='year_month', y='Total_Transactions', marker='o', linestyle='-')
plt.title('Transactions Over Time')
plt.xlabel('Month-Year')
plt.ylabel('Total Transactions')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=agg_features, x='Total_Transaction_Amount', y='Transaction_Frequency')
plt.title('Total Transaction Amount vs. Transaction Frequency')
plt.xlabel('Total Transaction Amount')
plt.ylabel('Transaction Frequency')
plt.show()

# %%
# Ensure 'Segment' is treated as a categorical type
agg_features['Segment'] = agg_features['Segment'].astype('category')

# Try plotting again
try:
    sns.pairplot(agg_features[['Average_Transaction_Amount', 'Total_Transaction_Amount', 'Transaction_Frequency', 'Segment']], hue='Segment', palette='viridis')
    plt.show()
except Exception as e:
    print(f"An error occurred: {e}")

# %%
plt.figure(figsize=(18, 8))  # Increase figure size
sns.barplot(
    x=data['to_randomly_generated_account'].value_counts().index,
    y=data['to_randomly_generated_account'].value_counts().values
)
plt.title('Transaction Frequencies to Different Accounts')
plt.xlabel('Account')
plt.ylabel('Number of Transactions')
plt.xticks(rotation=90)  # Rotate the labels vertically
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18, 8))
account_order = data['to_randomly_generated_account'].value_counts().index
sns.barplot(
    x='to_randomly_generated_account',
    y='to_randomly_generated_account',
    data=data,
    order=account_order,
    estimator=lambda x: len(x)
)
plt.title('Transaction Frequencies to Different Accounts')
plt.xlabel('Account')
plt.ylabel('Number of Transactions')
plt.xticks(rotation=90)  
plt.tight_layout()  
plt.show()

# %%
# Increase figure size for a clear view
plt.figure(figsize=(18, 8))

# Using seaborn's barplot to create a bar chart with different colors for each category
sns.barplot(
    x=data['to_randomly_generated_account'].value_counts().index,
    y=data['to_randomly_generated_account'].value_counts().values,
    palette=sns.color_palette("hsv", len(data['to_randomly_generated_account'].value_counts().index))  # Assign a unique color to each category
)

# Title and labels
plt.title('Transaction Frequencies to Different Accounts')
plt.xlabel('Account')
plt.ylabel('Number of Transactions')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Adjust the plot
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Generate a violin plot
plt.figure(figsize=(18, 8))
sns.violinplot(x='to_randomly_generated_account', y='monopoly_money_amount', data=data)
plt.title('Distribution of Transactions for Different Accounts')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Since the heatmap requires a numerical correlation matrix, we'll use the aggregated features
# We previously created which include 'Average_Transaction_Amount', 'Total_Transaction_Amount', and 'Transaction_Frequency'

# Calculate the correlation matrix
corr = agg_features[['Average_Transaction_Amount', 'Total_Transaction_Amount', 'Transaction_Frequency']].corr()

# Generate a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)
plt.title('Heatmap of Correlation Between Numerical Features')
plt.show()

# %%
time_series_data = data.groupby("not_happened_yet_date")['monopoly_money_amount'].sum().reset_index()
time_series_data
# Out:
#     not_happened_yet_date  monopoly_money_amount
# 0              2025-01-01                 380836
# 1              2025-01-02                 345083
# 2              2025-01-03                 641165
# 3              2025-01-04                 680632
# 4              2025-01-05                 664497
# ..                    ...                    ...
# 359            2025-12-27                 681929
# 360            2025-12-28                 681228
# 361            2025-12-29                 186713
# 362            2025-12-30                 186045
# 363            2025-12-31                 187427
#
# [364 rows x 2 columns]

# %%
time_series_data['not_happened_yet_date'] = pd.to_datetime(time_series_data['not_happened_yet_date'], format='%d/%m/%Y')

# %%
plt.figure(figsize=(18, 6))
sns.lineplot(data=time_series_data, x='not_happened_yet_date', y='monopoly_money_amount')
plt.title('Monopoly Money Amount Over Time')
plt.xlabel('Date')
plt.ylabel('Total Monopoly Money Amount')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the label encoder
label_encoder = LabelEncoder()

# Fit and transform the 'to_randomly_generated_account' column to convert text to integers
data['to_randomly_generated_account_int'] = label_encoder.fit_transform(data['to_randomly_generated_account'])

# Display the first few rows to verify the conversion
data[['to_randomly_generated_account', 'to_randomly_generated_account_int']].head()
# Out:
#   to_randomly_generated_account  to_randomly_generated_account_int
# 0                        CINEMA                                 12
# 1         TRANSFERED_TO_ACCOUNT                                 72
# 2         TRANSFERED_TO_ACCOUNT                                 72
# 3           HIPSTER_COFFEE_SHOP                                 31
# 4         TRANSFERED_TO_ACCOUNT                                 72

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the label encoder
label_encoder = LabelEncoder()

# Fit and transform the 'to_randomly_generated_account' column to convert text to integers
data['to_randomly_generated_account_int'] = label_encoder.fit_transform(data['to_randomly_generated_account'])

# Display the first few rows to verify the conversion
data[['to_randomly_generated_account', 'to_randomly_generated_account_int']].head()
# Out:
#   to_randomly_generated_account  to_randomly_generated_account_int
# 0                        CINEMA                                 12
# 1         TRANSFERED_TO_ACCOUNT                                 72
# 2         TRANSFERED_TO_ACCOUNT                                 72
# 3           HIPSTER_COFFEE_SHOP                                 31
# 4         TRANSFERED_TO_ACCOUNT                                 72

# %%
data
# Out:
#           from_totally_fake_account  monopoly_money_amount  \
# 0                             10371                      4
# 1                             88339                      2
# 2                             18555                      2
# 3                             18555                      4
# 4                             80792                      2
# ...                             ...                    ...
# 10148275                      32185                      3
# 10148276                      32185                      2
# 10148277                      57569                     14
# 10148278                       1490                      9
# 10148279                      53444                      3
#
#          to_randomly_generated_account not_happened_yet_date year_month  \
# 0                               CINEMA            2025-01-01    2025-01
# 1                TRANSFERED_TO_ACCOUNT            2025-01-01    2025-01
# 2                TRANSFERED_TO_ACCOUNT            2025-01-01    2025-01
# 3                  HIPSTER_COFFEE_SHOP            2025-01-01    2025-01
# 4                TRANSFERED_TO_ACCOUNT            2025-01-01    2025-01
# ...                                ...                   ...        ...
# 10148275                   COFFEE_SHOP            2025-12-31    2025-12
# 10148276                   COFFEE_SHOP            2025-12-31    2025-12
# 10148277                      WINE_BAR            2025-12-31    2025-12
# 10148278         TRANSFERED_TO_ACCOUNT            2025-12-31    2025-12
# 10148279           A_LOCAL_COFFEE_SHOP            2025-12-31    2025-12
#
#           to_randomly_generated_account_int
# 0                                        12
# 1                                        72
# 2                                        72
# 3                                        31
# 4                                        72
# ...                                     ...
# 10148275                                 15
# 10148276                                 15
# 10148277                                 78
# 10148278                                 72
# 10148279                                  2
#
# [10148280 rows x 6 columns]

# %%
data
# Out:
#           from_totally_fake_account  monopoly_money_amount  \
# 0                             10371                      4
# 1                             88339                      2
# 2                             18555                      2
# 3                             18555                      4
# 4                             80792                      2
# ...                             ...                    ...
# 10148275                      32185                      3
# 10148276                      32185                      2
# 10148277                      57569                     14
# 10148278                       1490                      9
# 10148279                      53444                      3
#
#          to_randomly_generated_account not_happened_yet_date year_month  \
# 0                               CINEMA            2025-01-01    2025-01
# 1                TRANSFERED_TO_ACCOUNT            2025-01-01    2025-01
# 2                TRANSFERED_TO_ACCOUNT            2025-01-01    2025-01
# 3                  HIPSTER_COFFEE_SHOP            2025-01-01    2025-01
# 4                TRANSFERED_TO_ACCOUNT            2025-01-01    2025-01
# ...                                ...                   ...        ...
# 10148275                   COFFEE_SHOP            2025-12-31    2025-12
# 10148276                   COFFEE_SHOP            2025-12-31    2025-12
# 10148277                      WINE_BAR            2025-12-31    2025-12
# 10148278         TRANSFERED_TO_ACCOUNT            2025-12-31    2025-12
# 10148279           A_LOCAL_COFFEE_SHOP            2025-12-31    2025-12
#
#           to_randomly_generated_account_int
# 0                                        12
# 1                                        72
# 2                                        72
# 3                                        31
# 4                                        72
# ...                                     ...
# 10148275                                 15
# 10148276                                 15
# 10148277                                 78
# 10148278                                 72
# 10148279                                  2
#
# [10148280 rows x 6 columns]

# %%
X = data.drop(["not_happened_yet_date", "to_randomly_generated_account", "year_month"],axis=1)

# %%
from sklearn.ensemble import IsolationForest

iso_forest = IsolationForest(n_estimators=100, contamination='auto', random_state=42)

iso_forest.fit(X)

outlier_predictions = iso_forest.predict(X)

fraud_predictions = pd.Series(outlier_predictions).apply(lambda x: 1 if x == -1 else 0)

data['predicted_fraud'] = fraud_predictions

fraud_predictions.value_counts()
# Out:
# 0    8249570
# 1    1898710
# Name: count, dtype: int64

# %%
fraud_predictions.value_counts().plot.bar()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualizing outliers identified by Isolation Forest
# We'll plot 'monopoly_money_amount' vs 'to_randomly_generated_account_int' with outlier indication
plt.figure(figsize=(10, 6))
sns.scatterplot(x='to_randomly_generated_account_int', y='monopoly_money_amount', hue='predicted_fraud', style='predicted_fraud', data=data, palette='Set1', markers=['o', 'X'])

plt.title('Outliers Detected in Transactions')
plt.xlabel('To Randomly Generated Account (Encoded)')
plt.ylabel('Monopoly Money Amount')
plt.legend(title='Predicted Fraud', labels=['Legitimate', 'Fraud'])

plt.show()

# %%
data
# Out:
#           from_totally_fake_account  monopoly_money_amount  \
# 0                             10371                      4
# 1                             88339                      2
# 2                             18555                      2
# 3                             18555                      4
# 4                             80792                      2
# ...                             ...                    ...
# 10148275                      32185                      3
# 10148276                      32185                      2
# 10148277                      57569                     14
# 10148278                       1490                      9
# 10148279                      53444                      3
#
#          to_randomly_generated_account not_happened_yet_date year_month  \
# 0                               CINEMA            2025-01-01    2025-01
# 1                TRANSFERED_TO_ACCOUNT            2025-01-01    2025-01
# 2                TRANSFERED_TO_ACCOUNT            2025-01-01    2025-01
# 3                  HIPSTER_COFFEE_SHOP            2025-01-01    2025-01
# 4                TRANSFERED_TO_ACCOUNT            2025-01-01    2025-01
# ...                                ...                   ...        ...
# 10148275                   COFFEE_SHOP            2025-12-31    2025-12
# 10148276                   COFFEE_SHOP            2025-12-31    2025-12
# 10148277                      WINE_BAR            2025-12-31    2025-12
# 10148278         TRANSFERED_TO_ACCOUNT            2025-12-31    2025-12
# 10148279           A_LOCAL_COFFEE_SHOP            2025-12-31    2025-12
#
#           to_randomly_generated_account_int  predicted_fraud
# 0                                        12                0
# 1                                        72                0
# 2                                        72                0
# 3                                        31                0
# 4                                        72                0
# ...                                     ...              ...
# 10148275                                 15                0
# 10148276                                 15                0
# 10148277                                 78                1
# 10148278                                 72                1
# 10148279                                  2                0
#
# [10148280 rows x 7 columns]

# %% [markdown]
# ## Visualisations:

# %%
import pandas as pd
import seaborn as sns

# Replace the following line with your actual data
# data = {'from_totally_fake_account': [...], 'monopoly_money_amount': [...]}

# Create a DataFrame with your data
# df = pd.DataFrame(data)

# Pair plot for the first two columns
sns.pairplot(data[['from_totally_fake_account', 'monopoly_money_amount']])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(data['from_totally_fake_account'], data['monopoly_money_amount'], alpha=0.01)
plt.xlabel('From Totally Fake Account')
plt.ylabel('Monopoly Money Amount')
plt.title('Relationship between From Totally Fake Account and Monopoly Money Amount')
plt.grid(True)
plt.show()

# %% [markdown]
# # Customer segmentation
# 1. Segmentation by 'Monopoly Money Amount' (Transaction Amount of user)
# 2. Segmentation by (count) Transaction Frequency (No. of transactions)
# 3. Segmentation by 'To Randomly Generated Account' (to whoom they are paying)
# 4. Segmentation by Date (On which date)
# 5. Combination of Segmentation Criteria (To get targets)

# %% [markdown]
# ### 1. Segmentation by 'Monopoly Money Amount' (Transaction Amount of user)

# %%
transaction_amount = data['monopoly_money_amount'].describe()
#transaction_amount

# %%
highest_spent_amount = data['monopoly_money_amount'].max()
highest_spent_amount   ## highest amount spent
# Out:
# 1995

# %%
highest_spent_amount = data['monopoly_money_amount'].min()
highest_spent_amount
# Out:
# 1

# %%
# Segmentation for customers based on transaction amount ranges

# bins for segmentation
#bins = [-float('inf'), 100, 800, 1000, float('inf')] ##  dividing range of values based on monopoly amount
#labels = ['Less', 'Medium', 'High', 'Very-High']  ## grouping bins.

# Create a new column for segment labels
#data['transaction_amount_segment'] = pd.cut(data['monopoly_money_amount'], bins=bins, labels=labels)
## pd.cut()- segment and sort data values into bins

## data['transaction_amount_segment']
#data['transaction_amount_segment'].value_counts()  ###count

# %%
# Automatic segmentation based on quantiles
transaction_amount_segment = pd.qcut(data['monopoly_money_amount'], q=3, labels=['Low segment', 'Medium', 'High segment'])

# Count the number of transactions in each segment
segment_counts = transaction_amount_segment.value_counts()
print(segment_counts)
# Out:
# monopoly_money_amount
# Low segment     3599719
# Medium          3409943
# High segment    3138618
# Name: count, dtype: int64

# %%
# average transaction amounts for each segment
average_amounts = data.groupby(transaction_amount_segment)['monopoly_money_amount'].mean()
print("Average Transaction Amounts by Segment:\n", average_amounts)
# Out:
# Average Transaction Amounts by Segment:
#  monopoly_money_amount
# Low segment      2.599610
# Medium           7.054123
# High segment    48.744555
# Name: monopoly_money_amount, dtype: float64

# %%
# Visualize customer patterns using transaction frequency
plt.figure(figsize=(8,3))
sns.countplot(x=transaction_amount_segment, edgecolor='black')
plt.xlabel('Segment')
plt.ylabel('Transaction Frequency')
plt.title('Transaction Frequency by Segment')
plt.show()

# %%
# Plot pie chart
plt.figure(figsize=(8,3))
plt.pie(segment_counts, labels=segment_counts.index, autopct='%1.2f%%', startangle=80)
plt.title('Customer Segmentation by Unique transactions')
plt.axis('equal')  
plt.show()

# %%
## get account numbers as well

# %%
## might be useful for marketing

# %% [markdown]
# ### 2. Segmentation by (count) Transaction Frequency (No. of transactions)

# %%
data['from_totally_fake_account'].value_counts()
# Out:
# 2331     2728
# 74448    2679
# 97033    2665
# 87324    2619
# 14877    2503
#          ...
# 30617     537
# 22078     524
# 68848     513
# 19964     504
# 55938     436
# Name: from_totally_fake_account, Length: 8142, dtype: int64

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Load dataset and preprocess data to create customer_data
# (Assuming you have previously defined and processed the 'data' DataFrame)

# Preprocessing steps to create customer_data
customer_data = data.groupby('from_totally_fake_account').agg({
    'monopoly_money_amount': ['count', 'sum']  # Calculate count (frequency) and sum (total spending)
}).reset_index()
customer_data.columns = ['from_totally_fake_account', 'transaction_frequency', 'total_spending']

# Select features for clustering
X = customer_data[['transaction_frequency', 'total_spending']]

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Determine the optimal number of clusters using the Elbow method
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

# Plot the Elbow curve
plt.figure(figsize=(5,3))
plt.plot(range(1, 11), wcss, marker='o', linestyle='--')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Perform K-means clustering with the chosen number of clusters
kmeans = KMeans(n_clusters=2, init='k-means++', random_state=42)
clusters = kmeans.fit_predict(X_scaled)

# Add cluster labels to the customer_data DataFrame
customer_data['cluster'] = clusters

# Display the segmentation results
print(customer_data.head())
# Out:
#    from_totally_fake_account  transaction_frequency  total_spending  cluster
# 0                       1000                   1710           28603        1
# 1                       1002                   1043           15590        0
# 2                       1006                   1841           18715        1
# 3                       1018                    805           15697        0
# 4                       1053                   1319           19397        0

# %%
# Visualize the clusters
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=clusters)  # cmap='viridis'
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, label='Centroids')
#plt.figure(figsize=(5,8))
plt.title('Customer Segmentation')
plt.xlabel('Transaction Frequency (Standardized)')
plt.ylabel('Total Spending (Standardized)')
plt.legend()
plt.show()

# %% [markdown]
# ### 3. Segmentation by 'To Randomly Generated Account' (to whoom they are paying)

# %%
#data.to_randomly_generated_account
data.to_randomly_generated_account.value_counts()
# Out:
# PUB                           834380
# BAR                           770414
# LOCAL_WATERING_HOLE           649043
# COFFEE_SHOP                   476099
# TOTALLY_A_REAL_COFFEE_SHOP    476064
#                                ...
# 74519                              2
# 24699                              2
# 1243                               2
# 95337                              2
# 20594                              1
# Name: to_randomly_generated_account, Length: 14300, dtype: int64

# %%
# Initialize counters
numeric_count = 0
categorical_count = 0

# Iterate through unique values in the column
for value in data['to_randomly_generated_account'].unique():
    # Try to convert the value to a numeric type
    try:
        float(value)
        # If successful, increment numeric count
        numeric_count += 1
    except ValueError:
        # If conversion fails, it's categorical
        categorical_count += 1

# Print the counts
print("Numeric values count:", numeric_count)
print("Categorical values count:", categorical_count)
# Out:
# Numeric values count: 14221
# Categorical values count: 79

# %%
# Print out the unique categorical values
categorical_values = data.loc[~data['to_randomly_generated_account'].apply(lambda x: str(x).replace('.', '').isdigit()), 'to_randomly_generated_account'].unique()
print("Unique categorical:")
print(categorical_values)
# Out:
# Unique categorical:
# ['CINEMA' 'HIPSTER_COFFEE_SHOP' 'TOTALLY_A_REAL_COFFEE_SHOP' 'COFFEE_SHOP'
#  'CAFE' 'A_CAFE' 'LOCAL_RESTAURANT' 'A_LOCAL_COFFEE_SHOP'
#  'GOURMET_COFFEE_SHOP' 'LOCAL_WATERING_HOLE' 'SANDWICH_SHOP' 'TOY_SHOP'
#  'PRETENTIOUS_COFFEE_SHOP' 'BAR' 'PUB' 'COMIC_BOOK_SHOP' 'LUNCH_VAN'
#  'DEPARTMENT_STORE' 'KEBAB_SHOP' 'WINE_BAR' 'ELECTRONICS_SHOP'
#  'RESTAURANT' 'LOCAL_PUB' 'LUNCH_PLACE' 'FASHION_SHOP'
#  'FASHIONABLE_SPORTSWARE_SHOP' 'SCHOOL_SUPPLY_STORE' 'LOCAL_BOOKSHOP'
#  'TRAINER_SHOP' 'BOOKSHOP' 'KIDS_ACTIVITY_CENTRE' 'VIDEO_GAME_STORE'
#  'CLOTHES_SHOP' 'TAKEAWAY_CURRY' 'TECH_SHOP' 'NERDY_BOOK_STORE'
#  'WHISKEY_BAR' 'PET_TOY_SHOP' 'DVD_SHOP' 'CHILDRENDS_SHOP' 'GAME_SHOP'
#  'INDIAN_RESTAURANT' 'COCKTAIL_BAR' 'RUNNING_SHOP' 'DIY_STORE' 'COOKSHOP'
#  'HOME_IMPROVEMENT_STORE' 'PET_SHOP' 'CHINESE_TAKEAWAY' 'BUTCHERS'
#  'SECOND_HAND_BOOKSHOP' 'G&T_BAR' 'GREENGROCER' 'JEWLLERY_SHOP'
#  'ACCESSORY_SHOP' 'TAKEAWAY' 'KIDS_CLOTHING_SHOP' 'SPORT_SHOP'
#  'STEAK_HOUSE' 'HIPSTER_ELECTRONICS_SHOP' 'CHINESE_RESTAURANT'
#  'SEAFOOD_RESAURANT' 'STREAMING_SERVICE' 'GYM' 'WHISKEY_SHOP' 'TEA_SHOP'
#  'RESTAURANT_VOUCHER' 'ROASTERIE' 'LIQUOR_STORE' 'TO_BEAN_OR_NOT_TO_BEAN'
#  'WINE_CELLAR' 'WE_HAVE_BEAN_WEIGHTING' 'LARGE_SUPERMARKET'
#  'EXPRESS_SUPERMARKET' 'BUTCHER' 'A_SUPERMARKET' 'THE_SUPERMARKET'
#  'FLORIST' 'TURKEY_FARM']

# %%
## grouping this 79 data points

# %%
# Group the data by 'from_totally_fake_account' and 'to_randomly_generated_account', then count occurrences
user_spending = data.groupby(['from_totally_fake_account', 'to_randomly_generated_account']).size().reset_index(name='transaction_count(generated)')
data
# Out:
#           from_totally_fake_account  monopoly_money_amount  \
# 0                             10371                      4
# 1                             88339                      2
# 2                             18555                      2
# 3                             18555                      4
# 4                             80792                      2
# ...                             ...                    ...
# 10148275                      32185                      3
# 10148276                      32185                      2
# 10148277                      57569                     14
# 10148278                       1490                      9
# 10148279                      53444                      3
#
#          to_randomly_generated_account not_happened_yet_date
# 0                               CINEMA            01/01/2025
# 1                                40544            01/01/2025
# 2                                85149            01/01/2025
# 3                  HIPSTER_COFFEE_SHOP            01/01/2025
# 4                                18555            01/01/2025
# ...                                ...                   ...
# 10148275                   COFFEE_SHOP            31/12/2025
# 10148276                   COFFEE_SHOP            31/12/2025
# 10148277                      WINE_BAR            31/12/2025
# 10148278                         57569            31/12/2025
# 10148279           A_LOCAL_COFFEE_SHOP            31/12/2025
#
# [10148280 rows x 4 columns]

# %%
# Find the index of the maximum spending for each user
max_spending_index = data.groupby('from_totally_fake_account')['monopoly_money_amount'].idxmax()

# Use the index to retrieve the corresponding 'to_randomly_generated_account' for the maximum spending
max_spending_by_user = data.loc[max_spending_index, ['from_totally_fake_account', 'to_randomly_generated_account', 'monopoly_money_amount']]
#max_spending_by_user

# %%
from kmodes.kmodes import KModes

# Extract the 'To Randomly Generated Account' column
to_randomly_generated_account = data['to_randomly_generated_account']

# Initialize KModes clustering with desired number of clusters
num_clusters = 5  # You can adjust this number as needed
km = KModes(n_clusters=num_clusters, init='Huang', n_init=5, verbose=1)

# Fit the KModes model to the data
clusters = km.fit_predict(to_randomly_generated_account.values.reshape(-1, 1))

# Add the cluster labels to the original data
data['cluster'] = clusters

# View the distribution of customers across clusters
print(data['cluster'].value_counts())

# Explore the characteristics of each cluster
for cluster_num in range(num_clusters):
    print(f"Cluster {cluster_num}:")
    print(data[data['cluster'] == cluster_num]['to_randomly_generated_account'].unique())
# Out:
# Init: initializing centroids

# %%
# !pip install kmodes
# Out:
# Collecting kmodes
# WARNING: There was an error checking the latest version of pip.
#   Using cached kmodes-0.12.2-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\bu23957\appdata\local\anaconda3\lib\site-packages (from kmodes) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\bu23957\appdata\local\anaconda3\lib\site-packages (from kmodes) (1.2.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\bu23957\appdata\local\anaconda3\lib\site-packages (from kmodes) (1.1.1)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\bu23957\appdata\local\anaconda3\lib\site-packages (from kmodes) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\bu23957\appdata\local\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->kmodes) (2.2.0)
# Installing collected packages: kmodes
# Successfully installed kmodes-0.12.2

# %%
# Initialize counters
numeric_count = 0
categorical_count = 0

# Iterate through unique values in the column
for value in data['to_randomly_generated_account'].unique():
    # Try to convert the value to a numeric type
    try:
        float(value)
        # If successful, increment numeric count
        numeric_count += 1
    except ValueError:
        # If conversion fails, it's categorical
        categorical_count += 1

# Print the counts
print("Numeric values count:", numeric_count)
print("Categorical values count:", categorical_count)

# %%
# Print out the unique categorical values
categorical_values = data.loc[~data['to_randomly_generated_account'].apply(lambda x: str(x).replace('.', '').isdigit()), 'to_randomly_generated_account'].unique()
print("Unique categorical values:")
print(categorical_values)

# %% [markdown]
# ### 4. Segmentation by Date (On which date)

# %%
# Convert 'not_happened_yet_date' column to datetime
data['not_happened_yet_date'] = pd.to_datetime(data['not_happened_yet_date'], format='%d/%m/%Y')

# %% [markdown]
# ### A. Weekly Segmentation

# %%
# Grouping by User and Week, calculating weekly spend
weekly_spending = data.groupby([data['from_totally_fake_account'], data['not_happened_yet_date'].dt.to_period('W')])['monopoly_money_amount'].sum()

# Resetting index and pivoting the data
weekly_spending = weekly_spending.reset_index().pivot(index='from_totally_fake_account', columns='not_happened_yet_date', values='monopoly_money_amount')

# Printing the weekly spend for each user
print("Weekly Spend by User:")
print(weekly_spending)

# %%
# Summing up the weekly spending for each user
weekly_spending['Total'] = weekly_spending.sum(axis=1)

# Sorting users based on their total spending
w_top_10_users = weekly_spending.nlargest(10, 'Total')

# Printing the top 10 users
print("Top 10 Users by Weekly Spending:")
print(w_top_10_users)

# %% [markdown]
# ### B. Monthly Segmentation:

# %%
# Grouping by User and Week, calculating weekly spend
m_spending = data.groupby([data['from_totally_fake_account'], data['not_happened_yet_date'].dt.to_period('M')])['monopoly_money_amount'].sum()

# Resetting index and pivoting the data
m_spending =m_spending.reset_index().pivot(index='from_totally_fake_account', columns='not_happened_yet_date', values='monopoly_money_amount')

# Printing the weekly spend for each user
print("m Spend by User:")
print(m_spending)

# %%
m_spending.head(3)
#m_spending.shape

# %%
# Summing up the weekly spending for each user
m_spending['Total'] = m_spending.sum(axis=1)

# Sorting users based on their total spending
m_top_10_users = m_spending.nlargest(10, 'Total')

# Printing the top 10 users
print("Top 10 Users by monthly Spending:")
print(m_top_10_users)

# %% [markdown]
# ### Yearly Segmentation:

# %%
# Grouping by User and Week, calculating weekly spend
y_spending = data.groupby([data['from_totally_fake_account'], data['not_happened_yet_date'].dt.to_period('Y')])['monopoly_money_amount'].sum()

# Resetting index and pivoting the data
y_spending =y_spending.reset_index().pivot(index='from_totally_fake_account', columns='not_happened_yet_date', values='monopoly_money_amount')

# Printing the weekly spend for each user
print("yearly Spend by User:")
print(y_spending)

# %%
# Summing up the weekly spending for each user
y_spending['Total'] = y_spending.sum(axis=1)

# Sorting users based on their total spending
y_top_10_users = y_spending.nlargest(10, 'Total')

# Printing the top 10 users
print("Top 10 Users by monthly Spending:")
print(y_top_10_users)

# %% [markdown]
# ### Lets see who spent more and where..... in whole data

# %%
# Calculate total amount spent by each user
user_spending = data.groupby('from_totally_fake_account')['monopoly_money_amount'].sum()

# Find the user who spent the most money
user_with_max_spending = user_spending.idxmax()
max_spending_amount = user_spending.max()

print("User with the most spending:", user_with_max_spending)
print("Total amount spent by the user:", max_spending_amount)

# Find the transaction types where the user spent the most money
transactions_of_max_spender = data[data['from_totally_fake_account'] == user_with_max_spending]
max_spending_transaction_type = transactions_of_max_spender.groupby('to_randomly_generated_account')['monopoly_money_amount'].sum().idxmax()

print("Transaction type where the user spent the most money:", max_spending_transaction_type)

# %% [markdown]
# ### WEEKLY MONTHLY YEARLY TOP USER PLOTS

# %%
# Define a colormap
colors = plt.cm.tab10.colors  # You can choose any other colormap

# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(25, 8))

# Plot for weekly spending
w_top_10_users.plot(kind='bar', y='Total', ax=axes[0], color=colors)
axes[0].set_title('Top 10 Users by Weekly Spending')
axes[0].set_xlabel('from_totally_fake_account')
axes[0].set_ylabel('monopoly_money_amount')

# Plot for monthly spending
m_top_10_users.plot(kind='bar', y='Total', ax=axes[1], color=colors)
axes[1].set_title('Top 10 Users by Monthly Spending')
axes[1].set_xlabel('from_totally_fake_account')
axes[1].set_ylabel('monopoly_money_amount')

# Plot for yearly spending
y_top_10_users.plot(kind='bar', y='Total', ax=axes[2], color=colors)
axes[2].set_title('Top 10 Users by Yearly Spending')
axes[2].set_xlabel('from_totally_fake_account')
axes[2].set_ylabel('monopoly_money_amount')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# ### 5. Combination of Segmentation Criteria (To get targets)

# %%
combined_targets = set(w_top_10_users.index) & set(m_top_10_users.index)

# Now you have a set of users who are top spenders both weekly and monthly
print("Combined Targets:")
print(combined_targets)

# %%
# Simulate spending data for each user
combined_targets_spending = {}
weeks = 20  # Assuming 20 weeks of spending data

for user_id in combined_targets:
    # Generate random spending values for each week
    spending_history = [random.randint(50, 500) for _ in range(weeks)]
    combined_targets_spending[user_id] = spending_history

# Plotting
plt.figure(figsize=(10,4))

for user_id, spending_history in combined_targets_spending.items():
    plt.plot(range(1, weeks + 1), spending_history, label=f'User {user_id}')

plt.title('Spending History of Combined Targets')
plt.xlabel('Week')
plt.ylabel('Spending')
plt.legend()
plt.grid(True)
plt.show()
